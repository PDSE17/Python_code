# %% [markdown]
# NLP (NATURAL LANGUAGE PROCESSING)-->
# NLP is a branch of A.I. and DL/ML that enables computer to understood,read,write,and generate human language.

# %% [markdown]
# Relationship AI-->ML-->DL-->NLP

# %% [markdown]
# The computer understood one language and translate into another
#
# for example
#
# a person know english hindi and he goes to japan and the local language is japanese he/she uses google translate

# %% [markdown]
# NLP
#
# work flow
# Sentence  ---> I am learning Machine learning.
#
# cleaning   ---> i am learning machine learning.
#
# Tokenization   "i","am","learning","machine","learning"
#
# remove stop words "learning","machine","learning"
#
# feature extraction  model/prediction

# %% [markdown]
# Types of NLP tasks
#
# 1.Text classification
#   classify text into categories
#   ex span | not span
#
# 2.Machine translation
#  translate one language to another
#  ex hindi ---> english | english ---> hindi

# %%
# day 36 code
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

text = "I love machine learning"
tokens = word_tokenize(text) 
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\PRASANJEET
# [nltk_data]     DAS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\PRASANJEET
# [nltk_data]     DAS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# ['I', 'love', 'machine', 'learning']

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

text = "My name is Prasanjeet Das"
tokens = word_tokenize(text) 
print(tokens)
# Out:
# ['My', 'name', 'is', 'Prasanjeet', 'Das']
# [nltk_data] Downloading package punkt to C:\Users\PRASANJEET
# [nltk_data]     DAS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\PRASANJEET
# [nltk_data]     DAS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
text = "I am learning Machine Learning"

words = word_tokenize(text)
print("tokenize")
print(words)

stop_words = set(stopwords.words("english"))
print("stop words")
print(stop_words)

# filter data 
filtered = []

for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)

# print filter data
print("filter data: ")
print(filtered)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\PRASANJEET
# [nltk_data]     DAS\AppData\Roaming\nltk_data...
# tokenize
# ['I', 'am', 'learning', 'Machine', 'Learning']
# stop words
# ...

# %%
# stemming --> converts words into their root form

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

print(stemmer.stem("playing"))
print(stemmer.stem("player"))
print(stemmer.stem("played"))
# Out:
# play
# player
# play

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

text = "My name is Prasanjeet Das"
tokens = word_tokenize(text) 
print(tokens)

# %%
# create a project with combination of word_tokenize,stopwords and PorterStemmer
